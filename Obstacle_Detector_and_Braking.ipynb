# %%
import cv2
import pypylon.pylon as py
import torch
import time
import numpy as np
from ultralytics import YOLO

# Load a MiDas model for depth estimation
model_type = "MiDaS_small"  # MiDaS v2.1 - Small (lowest accuracy, highest inference speed)
midas = torch.hub.load("intel-isl/MiDaS", model_type)

# Move model to GPU if available
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
midas.to(device)
midas.eval()

# Load transforms to resize and normalize the image
midas_transforms = torch.hub.load("intel-isl/MiDaS", "transforms")
transform = midas_transforms.small_transform

# Initialize Pylon camera
icam = py.InstantCamera(py.TlFactory.GetInstance().CreateFirstDevice())
icam.Open()
icam.PixelFormat = "RGB8"

# Load YOLOv8 model
yolo_model = YOLO('yolov8n.pt')

# ROI vertices for masking
roi_vertices = np.array([[(0.3 * 1920, 1200), (0.52 * 1920, 0.5 * 1200), (0.6 * 1920, 0.495 * 1200), (0.9 * 1920, 1200)]], dtype=np.int32)


while True:
    img = icam.GrabOne(4000)
    img_rgb = img.Array
    frame = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2BGR)

    start = time.time()

    # Depth estimation
    with torch.no_grad():
        prediction = midas(transform(frame).to(device))
        depth_map = prediction.squeeze().cpu().numpy()
        depth_map = cv2.normalize(depth_map, None, 0, 1, norm_type=cv2.NORM_MINMAX)
        
    # Mask the frame and apply YOLOv8 only within ROI
    mask = np.zeros_like(frame)
    cv2.fillPoly(mask, roi_vertices, (255, 255, 255))
    frame_roi = cv2.bitwise_and(frame, mask)
    
    # Convert frame_roi to the appropriate format for YOLOv8
    frame_roi = cv2.cvtColor(frame_roi, cv2.COLOR_BGR2RGB)
    
    # Perform object detection using YOLOv8
    yolo_outputs = yolo_model.predict(frame_roi)

    # Flag to determine if brake needs to be applied
    apply_brake = False

    for output in yolo_outputs:
        # Iterate over each bounding box in the current detection
        for j in range(len(output.boxes)):
            label = output.names[output.boxes.cls[j].item()]
            coordinates = output.boxes.xyxy[j].tolist()
            confidence = np.round(output.boxes.conf[j].item(), 2)
    
            # Extract the coordinates
            x_min, y_min, x_max, y_max = map(int, coordinates)
    
            # Draw bounding box on the normal frame
            cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
            cv2.rectangle(depth_map, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
    
            # Convert bounding box coordinates to depth map dimensions
            x_min_depth, y_min_depth = int(x_min * depth_map.shape[1] / frame.shape[1]), int(y_min * depth_map.shape[0] / frame.shape[0])
            x_max_depth, y_max_depth = int(x_max * depth_map.shape[1] / frame.shape[1]), int(y_max * depth_map.shape[0] / frame.shape[0])
            cv2.rectangle(depth_map, (x_min_depth, y_min_depth), (x_max_depth, y_max_depth), (0, 255, 0), 2)
    
            # Extract depth values within the bounding box
            depth_values = depth_map[y_min_depth:y_max_depth, x_min_depth:x_max_depth]
            
            # Check if the depth values are not empty
            if depth_values.size > 0:
                max_depth = np.max(depth_values)
                print(f"Maximum depth within bounding box: {max_depth}")

                # Apply brake if the maximum depth within the bounding box exceeds a threshold
                if max_depth > 0.6:
                    apply_brake = True
                    print("Apply Brake")

    # Create an image for displaying brake application information
    brake_info_img = np.zeros((100, 800, 3), dtype=np.uint8)
    brake_info_img.fill(255)  # White background

    # Add text to brake_info_img
    brake_info_text = "Apply Brake" if apply_brake else "No Brake Applied"
    cv2.putText(brake_info_img, brake_info_text, (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    end = time.time()
    totalTime = end - start
    fps = 1 / totalTime

    # Convert depth map to color for visualization
    depth_map_color = cv2.applyColorMap((depth_map * 255).astype(np.uint8), cv2.COLORMAP_JET)

    # Display depth map and normal frame
    cv2.putText(frame, f'FPS: {int(fps)}', (20, 70), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 255, 0), 2)
    cv2.polylines(frame, roi_vertices, True, (0, 255, 0), 2)  # Draw ROI on the normal frame
    depth_map_vis = cv2.resize(depth_map_color, (960, 600))
    frame_viz = cv2.resize(frame,(960, 600))

    # Display frames
    cv2.imshow('Depth Estimation', depth_map_vis)
    cv2.imshow('Normal Frame', frame_viz)
    cv2.imshow('Brake Info', brake_info_img)

    key = cv2.waitKey(1)
    if key == 27:
        break

icam.Close()
cv2.destroyAllWindows()
# Out:
# Using cache found in C:\Users\Vijay Meher/.cache\torch\hub\intel-isl_MiDaS_master
# Loading weights:  None
# Using cache found in C:\Users\Vijay Meher/.cache\torch\hub\rwightman_gen-efficientnet-pytorch_master
# Using cache found in C:\Users\Vijay Meher/.cache\torch\hub\intel-isl_MiDaS_master
# C:\Users\Vijay Meher\AppData\Local\Temp\ipykernel_9344\3657391658.py:24: DeprecationWarning: Setting a feature value by direct assignment is deprecated. Use <nodemap>.PixelFormat.Value = RGB8
#   icam.PixelFormat = "RGB8"
# 0: 416x640 (no detections), 46.6ms
# Speed: 7.6ms preprocess, 46.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 45.0ms
# Speed: 5.0ms preprocess, 45.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 40.2ms
# Speed: 5.1ms preprocess, 40.2ms inference, 0.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.8ms
# Speed: 4.9ms preprocess, 39.8ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 37.7ms
# Speed: 4.2ms preprocess, 37.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.1ms
# Speed: 4.0ms preprocess, 20.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.6ms
# Speed: 4.9ms preprocess, 20.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.0ms
# Speed: 4.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 19.9ms
# Speed: 4.0ms preprocess, 19.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 19.0ms
# Speed: 4.6ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.2ms
# Speed: 5.0ms preprocess, 20.2ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.0ms
# Speed: 5.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 23.5ms
# Speed: 4.0ms preprocess, 23.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.7ms
# Speed: 4.9ms preprocess, 39.7ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 24.0ms
# Speed: 4.0ms preprocess, 24.0ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.1ms
# Speed: 5.0ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.0ms
# Speed: 4.0ms preprocess, 20.0ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 24.6ms
# Speed: 6.2ms preprocess, 24.6ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 26.0ms
# Speed: 6.0ms preprocess, 26.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.0ms
# Speed: 4.0ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 22.0ms
# Speed: 3.0ms preprocess, 22.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.5ms
# Speed: 5.0ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.1ms
# Speed: 6.0ms preprocess, 39.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 37.7ms
# Speed: 6.3ms preprocess, 37.7ms inference, 3.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 37.9ms
# Speed: 6.4ms preprocess, 37.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 19.5ms
# Speed: 4.0ms preprocess, 19.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.4ms
# Speed: 4.0ms preprocess, 20.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.0ms
# Speed: 5.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.3ms
# Speed: 4.3ms preprocess, 20.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.0ms
# Speed: 4.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 19.5ms
# Speed: 6.0ms preprocess, 19.5ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.3ms
# Speed: 5.0ms preprocess, 20.3ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 19.5ms
# Speed: 4.0ms preprocess, 19.5ms inference, 1.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.9ms
# Speed: 6.0ms preprocess, 39.9ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 40.0ms
# Speed: 5.0ms preprocess, 40.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 38.1ms
# Speed: 5.5ms preprocess, 38.1ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 31.5ms
# Speed: 8.4ms preprocess, 31.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.6ms
# Speed: 4.0ms preprocess, 20.6ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.1ms
# Speed: 3.6ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.2ms
# Speed: 4.0ms preprocess, 20.2ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 21.3ms
# Speed: 5.1ms preprocess, 21.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.1ms
# Speed: 6.1ms preprocess, 39.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.5ms
# Speed: 5.0ms preprocess, 39.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.0ms
# Speed: 7.0ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 38.1ms
# Speed: 5.0ms preprocess, 38.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.5ms
# Speed: 4.0ms preprocess, 20.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 remote, 20.0ms
# Speed: 2.9ms preprocess, 20.0ms inference, 317.5ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.9255198836326599
# Apply Brake
#
# 0: 416x640 (no detections), 20.8ms
# Speed: 5.6ms preprocess, 20.8ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 19.5ms
# Speed: 5.0ms preprocess, 19.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 21
9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 21.0ms
# Speed: 4.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 truck, 20.0ms
# Speed: 5.0ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.3307707607746124
#
# 0: 416x640 1 truck, 20.1ms
# Speed: 4.0ms preprocess, 20.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.32708945870399475
#
# 0: 416x640 1 bus, 1 truck, 40.0ms
# Speed: 5.0ms preprocess, 40.0ms inference, 7.8ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.33343034982681274
# Maximum depth within bounding box: 0.33343034982681274
#
# 0: 416x640 (no detections), 39.0ms
# Speed: 7.0ms preprocess, 39.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 truck, 20.6ms
# Speed: 4.3ms preprocess, 20.6ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.3438793122768402
#
# 0: 416x640 (no detections), 20.0ms
# Speed: 5.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 truck, 21.7ms
# Speed: 4.0ms preprocess, 21.7ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.38322189450263977
#
# 0: 416x640 1 truck, 20.5ms
# Speed: 5.4ms preprocess, 20.5ms inference, 4.2ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.38264143466949463
#
# 0: 416x640 (no detections), 21.0ms
# Speed: 5.0ms preprocess, 21.0ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 bus, 20.6ms
# Speed: 4.2ms preprocess, 20.6ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.37842488288879395
#
# 0: 416x640 1 truck, 21.0ms
# Speed: 5.3ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.40520021319389343
#
# 0: 416x640 1 truck, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.3826337456703186
#
# 0: 416x640 1 bus, 40.2ms
# Speed: 6.1ms preprocess, 40.2ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.37965771555900574
#
# 0: 416x640 1 bus, 37.8ms
# Speed: 5.0ms preprocess, 37.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.38099032640457153
#
# 0: 416x640 (no detections), 19.0ms
# Speed: 5.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 bus, 19.5ms
# Speed: 5.0ms preprocess, 19.5ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.3467869460582733
#
# 0: 416x640 (no detections), 20.0ms
# Speed: 4.0ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 bus, 1 cell phone, 19.2ms
# Speed: 4.0ms preprocess, 19.2ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.4159560203552246
# Maximum depth within bounding box: 0.4159560203552246
#
# 0: 416x640 (no detections), 19.2ms
# Speed: 5.0ms preprocess, 19.2ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 truck, 19.7ms
# Speed: 4.1ms preprocess, 19.7ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.4036075174808502
#
# 0: 416x640 1 truck, 19.0ms
# Speed: 4.5ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.42074060440063477
#
# 0: 416x640 1 truck, 20.0ms
# Speed: 4.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.40333813428878784
#
# 0: 416x640 1 truck, 39.0ms
# Speed: 6.0ms preprocess, 39.0ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.4138045608997345
#
# 0: 416x640 1 truck, 20.0ms
# Speed: 7.0ms preprocess, 20.0ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.4109482765197754
#
# 0: 416x640 1 truck, 20.5ms
# Speed: 4.4ms preprocess, 20.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.4048990309238434
#
# 0: 416x640 1 truck, 20.5ms
# Speed: 4.0ms preprocess, 20.5ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.4315197467803955
#
# 0: 416x640 1 truck, 19.5ms
# Speed: 4.0ms preprocess, 19.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.3947088420391083
#
# 0: 416x640 1 truck, 20.4ms
# Speed: 3.1ms preprocess, 20.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.41361770033836365
#
# 0: 416x640 (no detections), 20.4ms
# Speed: 4.0ms preprocess, 20.4ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 truck, 20.6ms
# Speed: 4.5ms preprocess, 20.6ms inference, 3.7ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.4303877055644989
#
# 0: 416x640 (no detections), 23.6ms
# Speed: 4.2ms preprocess, 23.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.4ms
# Speed: 5.5ms preprocess, 39.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 40.1ms
# Speed: 5.0ms preprocess, 40.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 37.5ms
# Speed: 7.0ms preprocess, 37.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 18.5ms
# Speed: 4.0ms preprocess, 18.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 cell phone, 19.7ms
# Speed: 3.2ms preprocess, 19.7ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.45898380875587463
#
# 0: 416x640 1 bus, 1 cell phone, 19.0ms
# Speed: 5.0ms preprocess, 19.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.45594027638435364
# Maximum depth within bounding box: 0.45594027638435364
#
# 0: 416x640 1 bus, 1 truck, 19.2ms
# Speed: 4.0ms preprocess, 19.2ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.48536890745162964
# Maximum depth within bounding box: 0.48536890745162964
#
# 0: 416x640 1 bus, 1 truck, 19.3ms
# Speed: 4.0ms preprocess, 19.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.4875456392765045
# Maximum depth within bounding box: 0.4875456392765045
#
# 0: 416x640 1 bus, 1 truck, 19.8ms
# Speed: 5.0ms preprocess, 19.8ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.4976472854614258
# Maximum depth within bounding box: 0.4976472854614258
#
# 0: 416x640 1 bus, 19.9ms
# Speed: 3.3ms preprocess, 19.9ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.46719586849212646
#
# 0: 416x640 1 bus, 1 truck, 1 cell phone, 18.5ms
# Speed: 4.4ms preprocess, 18.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5017629861831665
# Maximum depth within bounding box: 0.5017629861831665
# Maximum depth within bounding box: 0.5017629861831665
#
# 0: 416x640 1 bus, 1 truck, 1 cell phone, 39.0ms
# Speed: 5.0ms preprocess, 39.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.4941038191318512
# Maximum depth within bounding box: 0.4941038191318512
# Maximum depth within bounding box: 0.4941038191318512
#
# 0: 416x640 1 bus, 1 truck, 1 cell phone, 20.4ms
# Speed: 3.0ms preprocess, 20.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5131077170372009
# Maximum depth within bounding box: 0.5131077170372009
# Maximum depth within bounding box: 0.5131077170372009
#
# 0: 416x640 1 bus, 1 cell phone, 23.2ms
# Speed: 4.0ms preprocess, 23.2ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5007465481758118
# Maximum depth within bounding box: 0.5007465481758118
#
# 0: 416x640 1 bus, 1 truck, 20.1ms
# Speed: 3.0ms preprocess, 20.1ms inference, 3.6ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5152676105499268
# Maximum depth within bounding box: 0.5152676105499268
#
# 0: 416x640 1 truck, 19.0ms
# Speed: 5.7ms preprocess, 19.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5340284109115601
#
# 0: 416x640 1 truck, 20.1ms
# Speed: 3.0ms preprocess, 20.1ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5370845794677734
#
# 0: 416x640 1 truck, 20.3ms
# Speed: 4.0ms preprocess, 20.3ms inference, 4.4ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5328389406204224
#
# 0: 416x640 (no detections), 19.4ms
# Speed: 5.0ms preprocess, 19.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 bus, 20.0ms
# Speed: 3.0ms preprocess, 20.0ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.4971253573894501
#
# 0: 416x640 1 bus, 1 truck, 38.2ms
# Speed: 5.0ms preprocess, 38.2ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5440620183944702
# Maximum depth within bounding box: 0.5440620183944702
#
# 0: 416x640 1 bus, 38.5ms
# Speed: 5.1ms preprocess, 38.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5261565446853638
#
# 0: 416x640 1 bus, 37.3ms
# Speed: 6.0ms preprocess, 37.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5350881814956665
#
# 0: 416x640 1 bus, 21.0ms
# Speed: 5.5ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5654491186141968
#
# 0: 416x640 1 bus, 24.8ms
# Speed: 5.0ms preprocess, 24.8ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5121811628341675
#
# 0: 416x640 1 bus, 20.0ms
# Speed: 5.0ms preprocess, 20.0ms inference, 4.4ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5410842895507812
#
# 0: 416x640 1 bus, 19.0ms
# Speed: 4.0ms preprocess, 19.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5735707879066467
#
# 0: 416x640 1 bus, 19.4ms
# Speed: 5.0ms preprocess, 19.4ms inference, 4.2ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.550419807434082
#
# 0: 416x640 1 bus, 19.9ms
# Speed: 4.9ms preprocess, 19.9ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5541031360626221
#
# 0: 416x640 1 bus, 19.9ms
# Speed: 4.3ms preprocess, 19.9ms inference, 2.7ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5600800514221191
#
# 0: 416x640 1 bus, 20.0ms
# Speed: 4.6ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.5715141892433167
#
# 0: 416x640 1 bus, 38.3ms
# Speed: 5.0ms preprocess, 38.3ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6186640858650208
# Apply Brake
#
# 0: 416x640 (no detections), 20.6ms
# Speed: 4.9ms preprocess, 20.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.1ms
# Speed: 2.9ms preprocess, 20.1ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 19.6ms
# Speed: 4.9ms preprocess, 19.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 19.6ms
# Speed: 4.1ms preprocess, 19.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 truck, 20.0ms
# Speed: 3.6ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.608357846736908
# Apply Brake
#
# 0: 416x640 (no detections), 20.2ms
# Speed: 4.7ms preprocess, 20.2ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 21.0ms
# Speed: 5.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.0ms
# Speed: 4.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 34.5ms
# Speed: 4.2ms preprocess, 34.5ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.8ms
# Speed: 5.4ms preprocess, 39.8ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.2ms
# Speed: 4.0ms preprocess, 39.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 21.2ms
# Speed: 5.0ms preprocess, 21.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 21.1ms
# Speed: 3.4ms preprocess, 21.1ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 23.0ms
# Speed: 4.0ms preprocess, 23.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 20.0ms
# Speed: 5.0ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 21.0ms
# Speed: 5.0ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 22.0ms
# Speed: 4.5ms preprocess, 22.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 21.7ms
# Speed: 4.6ms preprocess, 21.7ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 21.0ms
# Speed: 5.3ms preprocess, 21.0ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 21.0ms
# Speed: 4.5ms preprocess, 21.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 41.6ms
# Speed: 7.0ms preprocess, 41.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 truck, 40.6ms
# Speed: 5.0ms preprocess, 40.6ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6620432734489441
# Apply Brake
#
# 0: 416x640 1 bus, 1 truck, 38.2ms
# Speed: 5.0ms preprocess, 38.2ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6308340430259705
# Apply Brake
# Maximum depth within bounding box: 0.6308340430259705
# Apply Brake
#
# 0: 416x640 1 truck, 20.0ms
# Speed: 5.0ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6625065803527832
# Apply Brake
#
# 0: 416x640 (no detections), 20.0ms
# Speed: 4.4ms preprocess, 20.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 truck, 20.2ms
# Speed: 5.0ms preprocess, 20.2ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6762241125106812
# Apply Brake
#
# 0: 416x640 1 truck, 20.5ms
# Speed: 3.0ms preprocess, 20.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6715027093887329
# Apply Brake
#
# 0: 416x640 1 truck, 20.3ms
# Speed: 4.0ms preprocess, 20.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6617057919502258
# Apply Brake
#
# 0: 416x640 1 truck, 19.7ms
# Speed: 5.0ms preprocess, 19.7ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6949759721755981
# Apply Brake
#
# 0: 416x640 1 truck, 56.0ms
# Speed: 5.8ms preprocess, 56.0ms inference, 6.5ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.676230251789093
# Apply Brake
#
# 0: 416x640 1 truck, 21.1ms
# Speed: 4.0ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.7012262344360352
# Apply Brake
#
# 0: 416x640 1 truck, 39.0ms
# Speed: 6.0ms preprocess, 39.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6787720322608948
# Apply Brake
#
# 0: 416x640 1 truck, 20.6ms
# Speed: 4.1ms preprocess, 20.6ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6884694695472717
# Apply Brake
#
# 0: 416x640 1 truck, 20.0ms
# Speed: 5.0ms preprocess, 20.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6927104592323303
# Apply Brake
#
# 0: 416x640 1 truck, 20.5ms
# Speed: 5.0ms preprocess, 20.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6906574368476868
# Apply Brake
#
# 0: 416x640 1 truck, 21.4ms
# Speed: 4.1ms preprocess, 21.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6658052206039429
# Apply Brake
#
# 0: 416x640 1 truck, 20.0ms
# Speed: 5.0ms preprocess, 20.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6776231527328491
# Apply Brake
#
# 0: 416x640 1 truck, 21.0ms
# Speed: 3.0ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6907957196235657
# Apply Brake
#
# 0: 416x640 1 truck, 21.1ms
# Speed: 4.2ms preprocess, 21.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6679385304450989
# Apply Brake
#
# 0: 416x640 1 truck, 21.3ms
# Speed: 3.3ms preprocess, 21.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6874635219573975
# Apply Brake
#
# 0: 416x640 1 truck, 40.0ms
# Speed: 6.3ms preprocess, 40.0ms inference, 5.1ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6907711029052734
# Apply Brake
#
# 0: 416x640 1 truck, 38.0ms
# Speed: 6.1ms preprocess, 38.0ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6667920351028442
# Apply Brake
#
# 0: 416x640 1 truck, 37.4ms
# Speed: 5.1ms preprocess, 37.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6810848712921143
# Apply Brake
#
# 0: 416x640 1 truck, 21.0ms
# Speed: 8.0ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.693746030330658
# Apply Brake
#
# 0: 416x640 1 truck, 25.5ms
# Speed: 6.0ms preprocess, 25.5ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6640592813491821
# Apply Brake
#
# 0: 416x640 1 truck, 19.3ms
# Speed: 4.0ms preprocess, 19.3ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6693573594093323
# Apply Brake
#
# 0: 416x640 1 truck, 24.0ms
# Speed: 6.0ms preprocess, 24.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6986247301101685
# Apply Brake
#
# 0: 416x640 1 truck, 19.5ms
# Speed: 3.0ms preprocess, 19.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6954663395881653
# Apply Brake
#
# 0: 416x640 1 truck, 19.1ms
# Speed: 4.0ms preprocess, 19.1ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.689356803894043
# Apply Brake
#
# 0: 416x640 1 truck, 21.6ms
# Speed: 3.8ms preprocess, 21.6ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6760678887367249
# Apply Brake
#
# 0: 416x640 1 truck, 19.5ms
# Speed: 5.0ms preprocess, 19.5ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6909795999526978
# Apply Brake
#
# 0: 416x640 1 truck, 38.8ms
# Speed: 6.0ms preprocess, 38.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6981589198112488
# Apply Brake
#
# 0: 416x640 1 truck, 20.5ms
# Speed: 3.0ms preprocess, 20.5ms inference, 6.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.676850438117981
# Apply Brake
#
# 0: 416x640 1 truck, 20.4ms
# Speed: 4.0ms preprocess, 20.4ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6890767812728882
# Apply Brake
#
# 0: 416x640 1 truck, 20.9ms
# Speed: 4.1ms preprocess, 20.9ms inference, 3.5ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6829969882965088
# Apply Brake
#
# 0: 416x640 1 truck, 21.0ms
# Speed: 4.0ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6844572424888611
# Apply Brake
#
# 0: 416x640 1 truck, 20.3ms
# Speed: 4.0ms preprocess, 20.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.7061034440994263
# Apply Brake
#
# 0: 416x640 1 truck, 21.0ms
# Speed: 6.2ms preprocess, 21.0ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6814477443695068
# Apply Brake
#
# 0: 416x640 1 truck, 21.2ms
# Speed: 3.0ms preprocess, 21.2ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6757816672325134
# Apply Brake
#
# 0: 416x640 1 truck, 22.9ms
# Speed: 4.9ms preprocess, 22.9ms inference, 2.2ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6988915801048279
# Apply Brake
#
# 0: 416x640 1 truck, 40.0ms
# Speed: 6.0ms preprocess, 40.0ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6770052313804626
# Apply Brake
#
# 0: 416x640 1 truck, 40.2ms
# Speed: 5.1ms preprocess, 40.2ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6898413896560669
# Apply Brake
#
# 0: 416x640 1 truck, 38.5ms
# Speed: 5.0ms preprocess, 38.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.7024438977241516
# Apply Brake
#
# 0: 416x640 1 truck, 37.3ms
# Speed: 6.0ms preprocess, 37.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6672429442405701
# Apply Brake
#
# 0: 416x640 1 truck, 42.6ms
# Speed: 10.3ms preprocess, 42.6ms inference, 9.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6985660195350647
# Apply Brake
#
# 0: 416x640 1 truck, 38.1ms
# Speed: 8.0ms preprocess, 38.1ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6890315413475037
# Apply Brake
#
# 0: 416x640 1 truck, 27.1ms
# Speed: 11.0ms preprocess, 27.1ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.686514139175415
# Apply Brake
#
# 0: 416x640 1 truck, 44.5ms
# Speed: 7.2ms preprocess, 44.5ms inference, 16.7ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.7018096446990967
# Apply Brake
#
# 0: 416x640 1 truck, 46.6ms
# Speed: 8.0ms preprocess, 46.6ms inference, 9.3ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6874632239341736
# Apply Brake
#
# 0: 416x640 1 truck, 31.0ms
# Speed: 7.0ms preprocess, 31.0ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6931403279304504
# Apply Brake
#
# 0: 416x640 1 truck, 23.0ms
# Speed: 5.2ms preprocess, 23.0ms inference, 4.3ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6828248500823975
# Apply Brake
#
# 0: 416x640 1 truck, 39.4ms
# Speed: 14.2ms preprocess, 39.4ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6926934123039246
# Apply Brake
#
# 0: 416x640 1 truck, 21.5ms
# Speed: 5.0ms preprocess, 21.5ms inference, 6.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6934606432914734
# Apply Brake
#
# 0: 416x640 1 truck, 22.9ms
# Speed: 8.0ms preprocess, 22.9ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6853086948394775
# Apply Brake
#
# 0: 416x640 1 truck, 21.8ms
# Speed: 7.8ms preprocess, 21.8ms inference, 5.5ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6491941809654236
# Apply Brake
#
# 0: 416x640 1 truck, 20.8ms
# Speed: 6.1ms preprocess, 20.8ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6964967846870422
# Apply Brake
#
# 0: 416x640 1 truck, 20.0ms
# Speed: 5.0ms preprocess, 20.0ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.668140709400177
# Apply Brake
#
# 0: 416x640 1 truck, 20.0ms
# Speed: 5.1ms preprocess, 20.0ms inference, 4.7ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.699454665184021
# Apply Brake
#
# 0: 416x640 1 truck, 20.7ms
# Speed: 4.0ms preprocess, 20.7ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6954815983772278
# Apply Brake
#
# 0: 416x640 1 truck, 41.7ms
# Speed: 4.0ms preprocess, 41.7ms inference, 4.6ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6888314485549927
# Apply Brake
#
# 0: 416x640 1 truck, 39.4ms
# Speed: 4.0ms preprocess, 39.4ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6887935400009155
# Apply Brake
#
# 0: 416x640 1 truck, 21.1ms
# Speed: 4.2ms preprocess, 21.1ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6631565093994141
# Apply Brake
#
# 0: 416x640 1 bus, 1 truck, 20.9ms
# Speed: 4.6ms preprocess, 20.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6963993906974792
# Apply Brake
# Maximum depth within bounding box: 0.6963993906974792
# Apply Brake
#
# 0: 416x640 1 truck, 20.0ms
# Speed: 5.7ms preprocess, 20.0ms inference, 3.9ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6857340931892395
# Apply Brake
#
# 0: 416x640 1 truck, 20.6ms
# Speed: 4.6ms preprocess, 20.6ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6690686941146851
# Apply Brake
#
# 0: 416x640 1 truck, 21.0ms
# Speed: 4.6ms preprocess, 21.0ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6974840760231018
# Apply Brake
#
# 0: 416x640 1 truck, 21.1ms
# Speed: 3.5ms preprocess, 21.1ms inference, 3.2ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6978318095207214
# Apply Brake
#
# 0: 416x640 1 truck, 21.0ms
# Speed: 5.6ms preprocess, 21.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6502907276153564
# Apply Brake
#
# 0: 416x640 1 truck, 21.0ms
# Speed: 6.0ms preprocess, 21.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6938154697418213
# Apply Brake
#
# 0: 416x640 1 truck, 40.1ms
# Speed: 5.0ms preprocess, 40.1ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6745712161064148
# Apply Brake
#
# 0: 416x640 1 truck, 39.7ms
# Speed: 6.0ms preprocess, 39.7ms inference, 3.9ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6710533499717712
# Apply Brake
#
# 0: 416x640 1 truck, 37.1ms
# Speed: 5.0ms preprocess, 37.1ms inference, 4.1ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.658909797668457
# Apply Brake
#
# 0: 416x640 1 truck, 18.7ms
# Speed: 4.0ms preprocess, 18.7ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6762511730194092
# Apply Brake
#
# 0: 416x640 1 truck, 18.9ms
# Speed: 4.8ms preprocess, 18.9ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
# Maximum depth within bounding box: 0.6798838973045349
# ...
# Speed: 9.0ms preprocess, 34.1ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 38.7ms
# Speed: 9.0ms preprocess, 38.7ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 53.3ms
# Speed: 8.4ms preprocess, 53.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 46.8ms
# Speed: 10.0ms preprocess, 46.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 53.0ms
# Speed: 8.0ms preprocess, 53.0ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 38.6ms
# Speed: 11.0ms preprocess, 38.6ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 38.5ms
# Speed: 8.0ms preprocess, 38.5ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 38.6ms
# Speed: 11.0ms preprocess, 38.6ms inference, 5.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 38
ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 41.0ms
# Speed: 8.0ms preprocess, 41.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 40.8ms
# Speed: 11.0ms preprocess, 40.8ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 41.5ms
# Speed: 11.0ms preprocess, 41.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 46.0ms
# Speed: 15.6ms preprocess, 46.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 42.0ms
# Speed: 9.6ms preprocess, 42.0ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 29.0ms
# Speed: 11.9ms preprocess, 29.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 35.8ms
# Speed: 7.3ms preprocess, 35.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 32.1ms
# Speed: 9.0ms preprocess, 32.1ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 33.5ms
# Speed: 10.0ms preprocess, 33.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 28.3ms
# Speed: 10.8ms preprocess, 28.3ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 47.8ms
# Speed: 10.0ms preprocess, 47.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 51.0ms
# Speed: 9.1ms preprocess, 51.0ms inference, 3.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 42.0ms
# Speed: 8.6ms preprocess, 42.0ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 38.6ms
# Speed: 11.0ms preprocess, 38.6ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 29.7ms
# Speed: 8.0ms preprocess, 29.7ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 35.0ms
# Speed: 8.2ms preprocess, 35.0ms inference, 2.6ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 36.7ms
# Speed: 10.0ms preprocess, 36.7ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 38.9ms
# Speed: 7.1ms preprocess, 38.9ms inference, 4.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 35.5ms
# Speed: 9.9ms preprocess, 35.5ms inference, 6.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 44.0ms
# Speed: 15.1ms preprocess, 44.0ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 40.8ms
# Speed: 11.1ms preprocess, 40.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.1ms
# Speed: 9.0ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 28.3ms
# Speed: 7.2ms preprocess, 28.3ms inference, 3.4ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 34.0ms
# Speed: 9.0ms preprocess, 34.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 24.1ms
# Speed: 7.0ms preprocess, 24.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 36.1ms
# Speed: 10.0ms preprocess, 36.1ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 30.3ms
# Speed: 8.0ms preprocess, 30.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 42.0ms
# Speed: 11.2ms preprocess, 42.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 41.7ms
# Speed: 9.0ms preprocess, 41.7ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.1ms
# Speed: 9.6ms preprocess, 39.1ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.9ms
# Speed: 9.0ms preprocess, 39.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.0ms
# Speed: 7.5ms preprocess, 39.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 38.1ms
# Speed: 10.0ms preprocess, 38.1ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 32.7ms
# Speed: 10.0ms preprocess, 32.7ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 25.9ms
# Speed: 11.0ms preprocess, 25.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 34.1ms
# Speed: 7.0ms preprocess, 34.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 21.9ms
# Speed: 7.0ms preprocess, 21.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 33.0ms
# Speed: 10.0ms preprocess, 33.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 40.8ms
# Speed: 12.2ms preprocess, 40.8ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 38.0ms
# Speed: 12.0ms preprocess, 38.0ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 32.0ms
# Speed: 9.1ms preprocess, 32.0ms inference, 3.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 44.5ms
# Speed: 7.1ms preprocess, 44.5ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 37.9ms
# Speed: 10.0ms preprocess, 37.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 41.5ms
# Speed: 8.4ms preprocess, 41.5ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 36.6ms
# Speed: 8.0ms preprocess, 36.6ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 40.1ms
# Speed: 10.0ms preprocess, 40.1ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 36.6ms
# Speed: 9.0ms preprocess, 36.6ms inference, 4.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 37.1ms
# Speed: 9.0ms preprocess, 37.1ms inference, 2.9ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 39.0ms
# Speed: 7.4ms preprocess, 39.0ms inference, 2.8ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 55.6ms
# Speed: 11.0ms preprocess, 55.6ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 36.3ms
# Speed: 8.0ms preprocess, 36.3ms inference, 4.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 34.9ms
# Speed: 11.0ms preprocess, 34.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 (no detections), 27.7ms
# Speed: 8.1ms preprocess, 27.7ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
